# %%
from tensorflow.keras.models import Sequential
import tensorflow as tf
from tensorflow.keras.layers import Dense, SimpleRNN, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# Sample text corpus
corpus = [
    "I love coding",
    "Coding is fun",
    "Deep learning is great"
]

# Tokenization
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)
total_words = len(tokenizer.word_index) + 1

input_sequences = []
for line in corpus:
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)

# Padding sequences
max_sequence_len = max([len(seq) for seq in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))

# Create predictors and label
X, y = input_sequences[:, :-1], input_sequences[:, -1]
y = tf.keras.utils.to_categorical(y, num_classes=total_words)

# Build RNN model
model = Sequential()
model.add(Embedding(total_words, 10, input_length=max_sequence_len-1))
model.add(SimpleRNN(50))
model.add(Dense(total_words, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, y, epochs=100, verbose=1)

# Function to predict next word
def predict_next_word(seed_text):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
    predicted = np.argmax(model.predict(token_list), axis=-1)
    output_word = ""
    for word, index in tokenizer.word_index.items():
        if index == predicted:
            output_word = word
            break
    return output_word

# Example usage
seed_text = "Deep learning"
predicted_word = predict_next_word(seed_text)
print(f"Next word prediction for '{seed_text}': {predicted_word}")
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 1s/step - loss: 2.1838 - accuracy: 0.1429
# Epoch 2/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.1711 - accuracy: 0.5714
# Epoch 3/100
# 1/1 [==============================] - 0s 15ms/step - loss: 2.1585 - accuracy: 0.7143
# Epoch 4/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.1457 - accuracy: 0.7143
# Epoch 5/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.1329 - accuracy: 0.7143
# Epoch 6/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.1199 - accuracy: 0.7143
# Epoch 7/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.1065 - accuracy: 0.8571
# Epoch 8/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.0929 - accuracy: 0.8571
# Epoch 9/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.0787 - accuracy: 0.8571
# Epoch 10/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.0641 - accuracy: 0.7143
# Epoch 11/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.0490 - accuracy: 0.7143
# Epoch 12/100
# 1/1 [==============================] - 0s 15ms/step - loss: 2.0333 - accuracy: 0.7143
# Epoch 13/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.0168 - accuracy: 0.7143
# Epoch 14/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.9997 - accuracy: 0.7143
# Epoch 15/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.9819 - accuracy: 0.7143
# Epoch 16/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.9632 - accuracy: 0.5714
# Epoch 17/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.9437 - accuracy: 0.5714
# Epoch 18/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.9233 - accuracy: 0.5714
# Epoch 19/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.9020 - accuracy: 0.5714
# Epoch 20/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.8799 - accuracy: 0.5714
# Epoch 21/100
# 1/1 [==============================] - 0s 15ms/step - loss: 1.8568 - accuracy: 0.5714
# Epoch 22/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.8328 - accuracy: 0.5714
# Epoch 23/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.8079 - accuracy: 0.5714
# Epoch 24/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.7821 - accuracy: 0.5714
# Epoch 25/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.7555 - accuracy: 0.4286
# Epoch 26/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.7282 - accuracy: 0.4286
# Epoch 27/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.7002 - accuracy: 0.4286
# Epoch 28/100
# 1/1 [==============================] - 0s 25ms/step - loss: 1.6716 - accuracy: 0.4286
# Epoch 29/100
# 1/1 [==============================] - 0s 19ms/step - loss: 1.6425 - accuracy: 0.4286
# Epoch 30/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.6130 - accuracy: 0.4286
# Epoch 31/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.5833 - accuracy: 0.4286
# Epoch 32/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.5535 - accuracy: 0.4286
# Epoch 33/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.5236 - accuracy: 0.4286
# Epoch 34/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.4939 - accuracy: 0.4286
# Epoch 35/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.4645 - accuracy: 0.4286
# Epoch 36/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.4354 - accuracy: 0.4286
# Epoch 37/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.4067 - accuracy: 0.4286
# Epoch 38/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.3786 - accuracy: 0.4286
# Epoch 39/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.3510 - accuracy: 0.4286
# Epoch 40/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.3240 - accuracy: 0.4286
# Epoch 41/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.2976 - accuracy: 0.4286
# Epoch 42/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.2719 - accuracy: 0.4286
# Epoch 43/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.2469 - accuracy: 0.4286
# Epoch 44/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.2226 - accuracy: 0.4286
# Epoch 45/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1991 - accuracy: 0.4286
# Epoch 46/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1763 - accuracy: 0.4286
# Epoch 47/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.1544 - accuracy: 0.4286
# Epoch 48/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.1333 - accuracy: 0.4286
# Epoch 49/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.1131 - accuracy: 0.5714
# Epoch 50/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0938 - accuracy: 0.5714
# Epoch 51/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0754 - accuracy: 0.5714
# Epoch 52/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0578 - accuracy: 0.5714
# Epoch 53/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0410 - accuracy: 0.5714
# Epoch 54/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0249 - accuracy: 0.5714
# Epoch 55/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0094 - accuracy: 0.5714
# Epoch 56/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.9944 - accuracy: 0.5714
# Epoch 57/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.9799 - accuracy: 0.8571
# Epoch 58/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.9658 - accuracy: 0.8571
# Epoch 59/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.9520 - accuracy: 0.8571
# Epoch 60/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.9384 - accuracy: 0.8571
# Epoch 61/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.9251 - accuracy: 0.8571
# Epoch 62/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.9119 - accuracy: 0.8571
# Epoch 63/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.8988 - accuracy: 0.8571
# Epoch 64/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.8858 - accuracy: 0.8571
# Epoch 65/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.8729 - accuracy: 0.8571
# Epoch 66/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.8600 - accuracy: 0.8571
# Epoch 67/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.8472 - accuracy: 0.8571
# Epoch 68/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.8343 - accuracy: 0.8571
# Epoch 69/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.8215 - accuracy: 1.0000
# Epoch 70/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.8087 - accuracy: 1.0000
# Epoch 71/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7959 - accuracy: 1.0000
# Epoch 72/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.7831 - accuracy: 1.0000
# Epoch 73/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7703 - accuracy: 1.0000
# Epoch 74/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7575 - accuracy: 1.0000
# Epoch 75/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7448 - accuracy: 1.0000
# Epoch 76/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7321 - accuracy: 1.0000
# Epoch 77/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.7194 - accuracy: 1.0000
# Epoch 78/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7067 - accuracy: 1.0000
# Epoch 79/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6941 - accuracy: 1.0000
# Epoch 80/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6815 - accuracy: 1.0000
# Epoch 81/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6691 - accuracy: 1.0000
# Epoch 82/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6567 - accuracy: 1.0000
# Epoch 83/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6444 - accuracy: 1.0000
# Epoch 84/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6323 - accuracy: 1.0000
# Epoch 85/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6203 - accuracy: 1.0000
# Epoch 86/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6084 - accuracy: 1.0000
# Epoch 87/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.5966 - accuracy: 1.0000
# Epoch 88/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5850 - accuracy: 1.0000
# Epoch 89/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5736 - accuracy: 1.0000
# Epoch 90/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5624 - accuracy: 1.0000
# Epoch 91/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5513 - accuracy: 1.0000
# Epoch 92/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5404 - accuracy: 1.0000
# Epoch 93/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5297 - accuracy: 1.0000
# Epoch 94/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.5193 - accuracy: 1.0000
# Epoch 95/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5090 - accuracy: 1.0000
# Epoch 96/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.4990 - accuracy: 1.0000
# Epoch 97/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.4892 - accuracy: 1.0000
# Epoch 98/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.4796 - accuracy: 1.0000
# Epoch 99/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4702 - accuracy: 1.0000
# Epoch 100/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.4610 - accuracy: 1.0000
# 1/1 [==============================] - 0s 163ms/step
# Next word prediction for 'Deep learning': is
